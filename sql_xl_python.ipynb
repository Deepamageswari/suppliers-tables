# %%
import pandas as pd

# %%
suplier_details=pd.read_excel('AP_supp_details_dev.xls') #loaded the Suppliers Details excel file into pandas
suplier_details
# Out:
#      SUPPLIERID  SUPPLIER_NUMBER                      SUPPLIER_NAME  \
# 0         52093            30581                  ZZZ -OUTPOST24 AB
# 1         13198             8468                         LENOVO PCG
# 2         13198             8468                         LENOVO PCG
# 3         13198             8468                         LENOVO PCG
# 4         13198             8468                         LENOVO PCG
# ..          ...              ...                                ...
# 873     2075235            38214                  COLLECTING AGENCY
# 874       12377             6928  INTERMEC TECHNOLOGIES CORPORATION
# 875       11134              404                               DELL
# 876       11134              404                               DELL
# 877       11134              404                               DELL
#
#     TAXREGISTRATIONNUMBER               OU_NAME  \
# 0          SE556615210301  3104_NO_BV NORWAY_OU
# 1                     NaN  3104_NO_BV NORWAY_OU
# ...

# %%
type(suplier_details)
# Out:
# pandas.core.frame.DataFrame

# %%
len(suplier_details) #number of records in Supplier_details
# Out:
# 878

# %%
Supplier_Master=suplier_details.drop_duplicates(subset = ["SUPPLIERID"])
print(Supplier_Master)     #droping the duplicates and get the unique values
# Out:
#      SUPPLIERID  SUPPLIER_NUMBER                                SUPPLIER_NAME  \
# 0         52093            30581                            ZZZ -OUTPOST24 AB
# 1         13198             8468                                   LENOVO PCG
# 5          1334             1045                     ORANGE BUSINESS SERVICES
# 7         10493             2500                            DELOITTE & TOUCHE
# 15         3497              133                          HEWLETT PACKARD INC
# ..          ...              ...                                          ...
# 721      374210            34434                    ZZZ - PHILLIPINE AIRLINES
# 781       10869              317                                COMPUTACENTER
# 841      199210            33130  ZZZ - PETER F BROWN INDEPENDENT CONSULTANTX
# 844      439223            34805                            CAVERION NORGE AS
# 847      548214            35201                                  ZZZ - IB SA
#
# ...

# %%
len(unique_suplier_details)   #number of records in Suppler_Master
# Out:
# 104

# %%
import pymysql # import pymusql to connect the df to mysql

# %%
conn=pymysql.connect(host='localhost',port=int(3306),user='root',passwd='deeraj',db='suppliers') #connecting to mysql

# %%
Suppliers_Table=pd.read_sql_query("SELECT * FROM suppliers.suplier ",conn) #Read the table from mysql database using pandas
print(Suppliers_Table)
# Out:
#     SUPPLIERID  SUPPLIER_NUMBER                                SUPPLIER_NAME  \
# 0       175193            32407                                       ITELLO
# 1         6889            18725                                  BLUELON APS
# 2       490227            35094                ZZZ - Testing Solutions Group
# 3         1082              101                          ESP GLOBAL SERVICES
# 4         1082              101                          ESP GLOBAL SERVICES
# 5       210198            33371                                    DORMAKABA
# 6       210198            33371                                    DORMAKABA
# 7       210198            33371                                    DORMAKABA
# 8       210198            33371                                    DORMAKABA
# 9       210198            33371                                    DORMAKABA
# 10        1812              111                             FORMGRAPHICS LTD
# ...

# %%
type(Suppliers_Table)
# Out:
# pandas.core.frame.DataFrame

# %%
Suppliers_Address=Supplier_Master[['ADDRESS_LINE1','ADDRESS_LINE2','ADDRESS_LINE3','ADDRESS_LINE4','CITY','ZIP','STATE','COUNTRY','ADDRESS_STYLE']]
Suppliers_Address   #fetching only address column of the unique suppliers from the Supplier_Master df
# Out:
#                              ADDRESS_LINE1                     ADDRESS_LINE2  \
# 0                         BASTIONSGATAN 6A                               NaN
# 1    LENOVO TACHNOLOGY B.V - NORWAY BRANCH                 ROSENHOLMVEIEN 25
# 5          ORANGE BUSINESS HOLDINGS UK LTD                    BETJEMAN PLACE
# 7                      POSTBOKS 347 SKOYEN                KARENSLYST ALLE 20
# 15      HEWLETT PACKARD ENTERPRISE COMPANY               3000 HANOVER STREET
# ..                                     ...                               ...
# 721                    AIRCRAFT OPERATIONS  SERVICES DEPARTMENT PAL GATE 1-A
# 781                      1 WESTPOINT COURT                   GREAT PARK ROAD
# 841                   200 S BARRINGTON AVE                             49719
# 844                       OLE DEVIKSVEI 10                               NaN
# 847                                     HQ            1 PLACE DE LA PYRAMIDE
#
# ...

# %%
Suppliers_Contact=unique_suplier_details[['SUPPLIERID','SUPPLIER_NUMBER','SUPPLIER_NAME','TAXREGISTRATIONNUMBER','OU_NAME','PHONE','PERSON_FIRST_NAME','PERSON_LAST_NAME']]
Suppliers_Contact  #fetching only contact details of the unique suppliers from the supplier_master df
# Out:
#      SUPPLIERID  SUPPLIER_NUMBER                                SUPPLIER_NAME  \
# 0         52093            30581                            ZZZ -OUTPOST24 AB
# 1         13198             8468                                   LENOVO PCG
# 5          1334             1045                     ORANGE BUSINESS SERVICES
# 7         10493             2500                            DELOITTE & TOUCHE
# 15         3497              133                          HEWLETT PACKARD INC
# ..          ...              ...                                          ...
# 721      374210            34434                    ZZZ - PHILLIPINE AIRLINES
# 781       10869              317                                COMPUTACENTER
# 841      199210            33130  ZZZ - PETER F BROWN INDEPENDENT CONSULTANTX
# 844      439223            34805                            CAVERION NORGE AS
# 847      548214            35201                                  ZZZ - IB SA
#
# ...

# %%
from sqlalchemy import create_engine   #for connecting to the mysql database import the
                                        #create_engine method from sqlalchemy module

# %%
my_conn=create_engine("mysql+mysqldb://root:deeraj@localhost/suppliers") #give access to the mysql database

# %%
Suppliers_Contact.to_sql(con=my_conn,name='suppliers_contacts',if_exists='replace',index=False) 
#converting the fetched suppliers_contact dataframe into table (named-suppliers_contacts') in mysql database suppliers
#name=already exist table in mysql database  ,if_exists='replace'--if the table is already exist we have to replace

# %%
Suppliers_Address.to_sql(con=my_conn,name='suppliers_address1',if_exists='replace',index=False)
#converting the fetched suppliers_Address dataframe into table (named-suppliers_addres1') in mysql database suppliers
